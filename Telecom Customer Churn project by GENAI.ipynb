# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(r"C:\Users\Prath\Downloads\Customer Churn.csv")

# Display the first few rows of the DataFrame
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Display basic information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Replace blank spaces with 0 in TotalCharges column
df['TotalCharges'] = df['TotalCharges'].replace(' ', '0')

# Convert TotalCharges column to numeric datatype
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])

# %%
# checking it's done or not
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#  Check for null values in the dataset
print("Null Values in Dataset:")
print(df.isnull().sum())
# Out:
# Null Values in Dataset:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#  Describe numerical columns
print("\n\nDescription of Numerical Columns:")
print(df.describe())
# Out:
# Description of Numerical Columns:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
# checking duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 1. Define function to convert value
def convt(value):
    if value == 1:
        return "Yes"
    else:
        return "No"
# Apply this function to SeniorCitizen column
df['SeniorCitizen'] = df['SeniorCitizen'].apply(convt)

# %%
df.head(40)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            No     Yes         No       1           No
# 1   5575-GNVDE    Male            No      No         No      34          Yes
# 2   3668-QPYBK    Male            No      No         No       2          Yes
# 3   7795-CFOCW    Male            No      No         No      45           No
# 4   9237-HQITU  Female            No      No         No       2          Yes
# 5   9305-CDSKC  Female            No      No         No       8          Yes
# 6   1452-KIOVK    Male            No      No        Yes      22          Yes
# 7   6713-OKOMC  Female            No      No         No      10           No
# 8   7892-POOKP  Female            No     Yes         No      28          Yes
# 9   6388-TABGU    Male            No      No        Yes      62          Yes
# 10  9763-GRSKD    Male            No     Yes        Yes      13          Yes
# ...

# %% [markdown]
# #converted the value of seniorcitizen column with 1=="yes" else no

# %%
#count plot for churn customer and uncharn customer
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Churn')
plt.title('Count of Customers by Churn Status')
plt.xlabel('Churn Status')
plt.ylabel('Count of Customers')

# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
# pie chart for better understanding
churn_counts = df['Churn'].value_counts()
labels = churn_counts.index
sizes = churn_counts.values

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Customers by Churn Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %% [markdown]
# #from the given pie chart we get 26.5% of customer are churn out .
# #reason for that ?

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='gender', hue='Churn')
plt.title('Count of Customers by Gender with Churn Status')
plt.xlabel('Gender')
plt.ylabel('Count of Customers')
plt.legend(title='Churn')

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='SeniorCitizen', hue='Churn')
plt.title('Count of Customers by Senior Citizen Status with Churn Status')
plt.xlabel('Senior Citizen Status')
plt.ylabel('Count of Customers')
plt.legend(title='Churn')

# %% [markdown]
# #as the no.of senior citizen churned more

# %%
plt.figure(figsize=(8,5))
sns.histplot(x="tenure", data = df, hue="Churn")
plt.show()

# %% [markdown]
# #as we can see the some people starting churn by staring of 1,2 months and rest are still continuing

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Contract', hue="Churn")
plt.title('Count of Customers by Contract')
plt.xlabel('Contract')
plt.ylabel('Count of Customers')

# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# #as the people buying M-o-M are churned more then the rest of the others

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'SeniorCitizen_Converted'],
#       dtype='object')

# %%
# List of columns
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Define subplot grid
n_cols = 3  # number of plots in one row
n_rows = (len(cols) + n_cols - 1) // n_cols  # rows needed

plt.figure(figsize=(15,15))  # Adjust figure size

for i, col in enumerate(cols, 1):
    plt.subplot(n_rows, n_cols, i)  # create subplot
    sns.countplot(data=df, x=col, hue ="Churn")
    plt.title(col, fontsize=12)
    plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=df, x='PaymentMethod', hue="Churn")
plt.title('Count of Customers by Payment Mathod')
plt.xlabel('Payment Method')
plt.ylabel('Count of Customers')

# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# #Electronic check users have the highest churn risk at 45%, while automatic payment methods (bank transfer and credit card)
# #show the lowest churn rates at 15-17%
